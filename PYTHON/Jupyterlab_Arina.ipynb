# %% [markdown]
# # Holidays
#
# This notebook tells about holidays of one preson.

# %% [markdown]
# [Name](#Name)
# [Photo](#Photo)
# [Holiday destination](#Holiday-destination)
# [3 things that the person likes](#3-things-that-the-person-likes)
# [Video](#Video)

# %% [markdown]
# ## Name

# %%
Name = input("The name of this person is:")

# %% [markdown]
# ## Photo

# %% [markdown]
# This is this person:
# ![sailor.png](attachment:sailor.png)

# %% [markdown]
# ## Holiday destination

# %% [markdown]
# This person's favourite holiday destination is the Moon Kingdom :
# ![the_moon_kingdom.png](attachment:the_moon_kingdom.png)

# %% [markdown]
# ## 3 things that the person likes

# %% [markdown]
# The person likes to do here:
#
#  - _go ice-scating_
#  - _meet Mamoru_
#  - _watch the Earth_

# %% [markdown]
# ## Video

# %%
from IPython.display import YouTubeVideo

# %%
video=YouTubeVideo ("UaQdTBmR-Oo")

# %%
display(video)
