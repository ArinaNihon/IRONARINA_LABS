# %% [markdown]
# # Lab Case Study
#
# ## Scenario
#
# You are working as an analyst for an auto insurance company. The company has collected some data about its customers including their demographics, education, employment, policy details, vehicle information on which insurance policy is, and claim amounts. You will help the senior management with some business questions that will help them to better understand their customers, improve their services, and improve profitability.
#
# ## Business Objectives
#
# - Retain customers,
# - analyze relevant customer data,
# - develop focused customer retention programs.
#
# Based on the analysis, take targeted actions to increase profitable customer response, retention, and growth.
#
# ## Activities
#
# Refer to the [`Activities.md`](./Activities.md) file where you will find guidelines for some of the activities that you want to do.
#
# ## Data
#
# The csv files is provided in the folder. The columns in the file are self-explanatory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %% [markdown]
# # Reading Data

# %%
file1 = pd.read_csv('Data/file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
file2 = pd.read_csv('Data/file2.csv')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
file3 = pd.read_csv('Data/file3.csv')
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
file1 = file1.reindex(sorted(file1.columns), axis=1)
file2 = file2.reindex(sorted(file2.columns), axis=1)
file3 = file3.reindex(sorted(file3.columns), axis=1)

# %%
def rename_columns(file1):
    file1.rename(columns={'GENDER':'Gender','ST':'State'}, inplace=True )
    return file1

# %%
file1=rename_columns(file1)
file1
# Out:
#      Customer Customer Lifetime Value             Education Gender   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 4003      NaN                     NaN                   NaN    NaN      NaN
# 4004      NaN                     NaN                   NaN    NaN      NaN
# 4005      NaN                     NaN                   NaN    NaN      NaN
# 4006      NaN                     NaN                   NaN    NaN      NaN
# 4007      NaN                     NaN                   NaN    NaN      NaN
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 4003                   NaN                       NaN             NaN
# 4004                   NaN                       NaN             NaN
# 4005                   NaN                       NaN             NaN
# 4006                   NaN                       NaN             NaN
# 4007                   NaN                       NaN             NaN
#
#            State  Total Claim Amount  Vehicle Class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 4003         NaN                 NaN            NaN
# 4004         NaN                 NaN            NaN
# 4005         NaN                 NaN            NaN
# 4006         NaN                 NaN            NaN
# 4007         NaN                 NaN            NaN
#
# [4008 rows x 11 columns]

# %%
def rename_columns(file2):
    file2.rename(columns={'GENDER':'Gender','ST':'State'}, inplace=True )
    return file2

# %%
file2=rename_columns(file2)
file2
# Out:
#     Customer Customer Lifetime Value Education Gender  Income  \
# 0    GS98873              323912.47%  Bachelor      F   16061
# 1    CW49887              462680.11%    Master      F   79487
# 2    MY31220              899704.02%   College      F   54230
# 3    UH35128             2580706.30%   College      F   71210
# 4    WH52799              380812.21%   College      F   94903
# ..       ...                     ...       ...    ...     ...
# 991  HV85198              847141.75%    Master      M   63513
# 992  BS91566              543121.91%   College      F   58161
# 993  IL40123              568964.41%   College      F   83640
# 994  MY32149              368672.38%    Master      F       0
# 995  SA91515              399258.39%  Bachelor      M       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                      88                    1/0/00   Personal Auto
# 1                     114                    1/0/00    Special Auto
# 2                     112                    1/0/00   Personal Auto
# 3                     214                    1/1/00   Personal Auto
# 4                      94                    1/0/00  Corporate Auto
# ..                    ...                       ...             ...
# 991                    70                    1/0/00   Personal Auto
# 992                    68                    1/0/00  Corporate Auto
# 993                    70                    1/0/00  Corporate Auto
# 994                    96                    1/0/00   Personal Auto
# 995                   111                    1/0/00   Personal Auto
#
#           State  Total Claim Amount  Vehicle Class
# 0       Arizona          633.600000  Four-Door Car
# 1    California          547.200000            SUV
# 2    California          537.600000   Two-Door Car
# 3        Oregon         1027.200000     Luxury Car
# 4       Arizona          451.200000   Two-Door Car
# ..          ...                 ...            ...
# 991     Arizona          185.667213  Four-Door Car
# 992     Arizona          140.747286  Four-Door Car
# 993      Nevada          471.050488   Two-Door Car
# 994  California           28.460568   Two-Door Car
# 995  California          700.349052            SUV
#
# [996 rows x 11 columns]

# %%
def rename_columns(file3):
    file3.rename(columns={'GENDER':'Gender','ST':'State'}, inplace=True )
    return file3

# %%
file=rename_columns(file3)
file3
# Out:
#      Customer  Customer Lifetime Value             Education Gender  Income  \
# 0     SA25987              3479.137523  High School or Below      M       0
# 1     TB86706              2502.637401                Master      M       0
# 2     ZL73902              3265.156348              Bachelor      F   25820
# 3     KX23516              4455.843406  High School or Below      F       0
# 4     FN77294              7704.958480  High School or Below      M   30366
# ...       ...                      ...                   ...    ...     ...
# 7065  LA72316             23405.987980              Bachelor      M   71941
# 7066  PK87824              3096.511217               College      F   21604
# 7067  TD14365              8163.890428              Bachelor      M       0
# 7068  UP19263              7524.442436               College      M   21941
# 7069  Y167826              2611.836866               College      M       0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                      104                          0   Personal Auto
# 1                       66                          0   Personal Auto
# 2                       82                          0   Personal Auto
# 3                      121                          0   Personal Auto
# 4                      101                          2   Personal Auto
# ...                    ...                        ...             ...
# 7065                    73                          0   Personal Auto
# 7066                    79                          0  Corporate Auto
# 7067                    85                          3  Corporate Auto
# 7068                    96                          0   Personal Auto
# 7069                    77                          0  Corporate Auto
#
#            State  Total Claim Amount  Vehicle Class
# 0     Washington          499.200000   Two-Door Car
# 1        Arizona            3.468912   Two-Door Car
# 2         Nevada          393.600000  Four-Door Car
# 3     California          699.615192            SUV
# 4     California          484.800000            SUV
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %% [markdown]
# # Aggregating data into one Data Frame

# %%
def load_original_data():
    return pd.concat([file1,file2,file3], axis=0)

# %%
hk_df=load_original_data()
hk_df
# Out:
#      Customer Customer Lifetime Value             Education Gender   Income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316             23405.98798              Bachelor      M  71941.0
# 7066  PK87824             3096.511217               College      F  21604.0
# 7067  TD14365             8163.890428              Bachelor      M      0.0
# 7068  UP19263             7524.442436               College      M  21941.0
# 7069  Y167826             2611.836866               College      M      0.0
#
#       Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#            State  Total Claim Amount  Vehicle Class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [12074 rows x 11 columns]

# %%
def lower_case_column_names(hk_df):
    hk_df.columns=[i.lower() for i in hk_df.columns]
    return hk_df

# %%
hk_df=lower_case_column_names(hk_df)
hk_df
# Out:
#      customer customer lifetime value             education gender   income  \
# 0     RB50392                     NaN                Master    NaN      0.0
# 1     QZ44356              697953.59%              Bachelor      F      0.0
# 2     AI49188             1288743.17%              Bachelor      F  48767.0
# 3     WW63253              764586.18%              Bachelor      M      0.0
# 4     GA49547              536307.65%  High School or Below      M  36357.0
# ...       ...                     ...                   ...    ...      ...
# 7065  LA72316             23405.98798              Bachelor      M  71941.0
# 7066  PK87824             3096.511217               College      F  21604.0
# 7067  TD14365             8163.890428              Bachelor      M      0.0
# 7068  UP19263             7524.442436               College      M  21941.0
# 7069  Y167826             2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 7065  California          198.234764  Four-Door Car
# 7066  California          379.200000  Four-Door Car
# 7067  California          790.784983  Four-Door Car
# 7068  California          691.200000  Four-Door Car
# 7069  California          369.600000   Two-Door Car
#
# [12074 rows x 11 columns]

# %%
hk=hk_df.reset_index()
hk
# Out:
#        index customer customer lifetime value             education gender  \
# 0          0  RB50392                     NaN                Master    NaN
# 1          1  QZ44356              697953.59%              Bachelor      F
# 2          2  AI49188             1288743.17%              Bachelor      F
# 3          3  WW63253              764586.18%              Bachelor      M
# 4          4  GA49547              536307.65%  High School or Below      M
# ...      ...      ...                     ...                   ...    ...
# 12069   7065  LA72316             23405.98798              Bachelor      M
# 12070   7066  PK87824             3096.511217               College      F
# 12071   7067  TD14365             8163.890428              Bachelor      M
# 12072   7068  UP19263             7524.442436               College      M
# 12073   7069  Y167826             2611.836866               College      M
#
#         income  monthly premium auto number of open complaints  \
# 0          0.0                1000.0                    1/0/00
# 1          0.0                  94.0                    1/0/00
# 2      48767.0                 108.0                    1/0/00
# 3          0.0                 106.0                    1/0/00
# 4      36357.0                  68.0                    1/0/00
# ...        ...                   ...                       ...
# 12069  71941.0                  73.0                         0
# 12070  21604.0                  79.0                         0
# 12071      0.0                  85.0                         3
# 12072  21941.0                  96.0                         0
# 12073      0.0                  77.0                         0
#
#           policy type       state  total claim amount  vehicle class
# 0       Personal Auto  Washington            2.704934  Four-Door Car
# 1       Personal Auto     Arizona         1131.464935  Four-Door Car
# 2       Personal Auto      Nevada          566.472247   Two-Door Car
# 3      Corporate Auto  California          529.881344            SUV
# 4       Personal Auto  Washington           17.269323  Four-Door Car
# ...               ...         ...                 ...            ...
# 12069   Personal Auto  California          198.234764  Four-Door Car
# 12070  Corporate Auto  California          379.200000  Four-Door Car
# 12071  Corporate Auto  California          790.784983  Four-Door Car
# 12072   Personal Auto  California          691.200000  Four-Door Car
# 12073  Corporate Auto  California          369.600000   Two-Door Car
#
# [12074 rows x 12 columns]

# %% [markdown]
# ## Dropping unnecessary columns

# %%
def drop_columns(hk) :
    hk.drop(columns=["index","customer"], inplace=True)
    return hk

# %%
drop_columns(hk)
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                  697953.59%              Bachelor      F      0.0
# 2                 1288743.17%              Bachelor      F  48767.0
# 3                  764586.18%              Bachelor      M      0.0
# 4                  536307.65%  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 12069             23405.98798              Bachelor      M  71941.0
# 12070             3096.511217               College      F  21604.0
# 12071             8163.890428              Bachelor      M      0.0
# 12072             7524.442436               College      M  21941.0
# 12073             2611.836866               College      M      0.0
#
#        monthly premium auto number of open complaints     policy type  \
# 0                    1000.0                    1/0/00   Personal Auto
# 1                      94.0                    1/0/00   Personal Auto
# 2                     108.0                    1/0/00   Personal Auto
# 3                     106.0                    1/0/00  Corporate Auto
# 4                      68.0                    1/0/00   Personal Auto
# ...                     ...                       ...             ...
# 12069                  73.0                         0   Personal Auto
# 12070                  79.0                         0  Corporate Auto
# 12071                  85.0                         3  Corporate Auto
# 12072                  96.0                         0   Personal Auto
# 12073                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0      Washington            2.704934  Four-Door Car
# 1         Arizona         1131.464935  Four-Door Car
# 2          Nevada          566.472247   Two-Door Car
# 3      California          529.881344            SUV
# 4      Washington           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 12069  California          198.234764  Four-Door Car
# 12070  California          379.200000  Four-Door Car
# 12071  California          790.784983  Four-Door Car
# 12072  California          691.200000  Four-Door Car
# 12073  California          369.600000   Two-Door Car
#
# [12074 rows x 10 columns]

# %%
ck=hk.drop_duplicates()
ck
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                  697953.59%              Bachelor      F      0.0
# 2                 1288743.17%              Bachelor      F  48767.0
# 3                  764586.18%              Bachelor      M      0.0
# 4                  536307.65%  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 12069             23405.98798              Bachelor      M  71941.0
# 12070             3096.511217               College      F  21604.0
# 12071             8163.890428              Bachelor      M      0.0
# 12072             7524.442436               College      M  21941.0
# 12073             2611.836866               College      M      0.0
#
#        monthly premium auto number of open complaints     policy type  \
# 0                    1000.0                    1/0/00   Personal Auto
# 1                      94.0                    1/0/00   Personal Auto
# 2                     108.0                    1/0/00   Personal Auto
# 3                     106.0                    1/0/00  Corporate Auto
# 4                      68.0                    1/0/00   Personal Auto
# ...                     ...                       ...             ...
# 12069                  73.0                         0   Personal Auto
# 12070                  79.0                         0  Corporate Auto
# 12071                  85.0                         3  Corporate Auto
# 12072                  96.0                         0   Personal Auto
# 12073                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0      Washington            2.704934  Four-Door Car
# 1         Arizona         1131.464935  Four-Door Car
# 2          Nevada          566.472247   Two-Door Car
# 3      California          529.881344            SUV
# 4      Washington           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 12069  California          198.234764  Four-Door Car
# 12070  California          379.200000  Four-Door Car
# 12071  California          790.784983  Four-Door Car
# 12072  California          691.200000  Four-Door Car
# 12073  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch=ck.reset_index()
ch
# Out:
#       index customer lifetime value             education gender   income  \
# 0         0                     NaN                Master    NaN      0.0
# 1         1              697953.59%              Bachelor      F      0.0
# 2         2             1288743.17%              Bachelor      F  48767.0
# 3         3              764586.18%              Bachelor      M      0.0
# 4         4              536307.65%  High School or Below      M  36357.0
# ...     ...                     ...                   ...    ...      ...
# 8877  12069             23405.98798              Bachelor      M  71941.0
# 8878  12070             3096.511217               College      F  21604.0
# 8879  12071             8163.890428              Bachelor      M      0.0
# 8880  12072             7524.442436               College      M  21941.0
# 8881  12073             2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 11 columns]

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8882 entries, 0 to 8881
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      8882 non-null   int64
#  1   customer lifetime value    8874 non-null   object
#  2   education                  8881 non-null   object
#  3   gender                     8759 non-null   object
#  4   income                     8881 non-null   float64
#  5   monthly premium auto       8881 non-null   float64
#  6   number of open complaints  8881 non-null   object
#  7   policy type                8881 non-null   object
#  8   state                      8881 non-null   object
#  9   total claim amount         8881 non-null   float64
#  10  vehicle class              8881 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 763.4+ KB

# %% [markdown]
# ##  Working with data types

# %%
ch['customer lifetime value'] = ch['customer lifetime value'].apply(lambda x: float(x.rstrip(x[-1]))/100 if str(x).endswith('%') else x)

# %%
ch
# Out:
#       index  customer lifetime value             education gender   income  \
# 0         0                      NaN                Master    NaN      0.0
# 1         1              6979.535900              Bachelor      F      0.0
# 2         2             12887.431700              Bachelor      F  48767.0
# 3         3              7645.861800              Bachelor      M      0.0
# 4         4              5363.076500  High School or Below      M  36357.0
# ...     ...                      ...                   ...    ...      ...
# 8877  12069             23405.987980              Bachelor      M  71941.0
# 8878  12070              3096.511217               College      F  21604.0
# 8879  12071              8163.890428              Bachelor      M      0.0
# 8880  12072              7524.442436               College      M  21941.0
# 8881  12073              2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 11 columns]

# %%
def drop_columns(ch) :
    ch.drop(columns=["index"], inplace=True)
    return ch

# %%
drop_columns(ch)
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                 6979.535900              Bachelor      F      0.0
# 2                12887.431700              Bachelor      F  48767.0
# 3                 7645.861800              Bachelor      M      0.0
# 4                 5363.076500  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 8877             23405.987980              Bachelor      M  71941.0
# 8878              3096.511217               College      F  21604.0
# 8879              8163.890428              Bachelor      M      0.0
# 8880              7524.442436               College      M  21941.0
# 8881              2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['customer lifetime value'].astype
# Out:
# <bound method NDFrame.astype of 0                NaN
# 1        6979.535900
# 2       12887.431700
# 3        7645.861800
# 4        5363.076500
#             ...
# 8877    23405.987980
# 8878     3096.511217
# 8879     8163.890428
# 8880     7524.442436
# 8881     2611.836866
# Name: customer lifetime value, Length: 8882, dtype: float64>

# %%
ch['customer lifetime value'] = ch['customer lifetime value'].astype(float)
ch
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                 6979.535900              Bachelor      F      0.0
# 2                12887.431700              Bachelor      F  48767.0
# 3                 7645.861800              Bachelor      M      0.0
# 4                 5363.076500  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 8877             23405.987980              Bachelor      M  71941.0
# 8878              3096.511217               College      F  21604.0
# 8879              8163.890428              Bachelor      M      0.0
# 8880              7524.442436               College      M  21941.0
# 8881              2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# 1                     94.0                    1/0/00   Personal Auto
# 2                    108.0                    1/0/00   Personal Auto
# 3                    106.0                    1/0/00  Corporate Auto
# 4                     68.0                    1/0/00   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %% [markdown]
# ## Cleaning the number of open complaints and extracting the middle number

# %%
ch['number of open complaints'].value_counts()
# Out:
# 0         5421
# 1/0/00    1618
# 1          749
# 2          279
# 1/1/00     245
# 3          221
# 4          114
# 1/2/00      93
# 1/3/00      58
# 5           43
# 1/4/00      28
# 1/5/00      12
# Name: number of open complaints, dtype: int64

# %%
rep = lambda x: x.replace('1/0/00','0') if x=='1/0/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
rep = lambda x: x.replace('1/1/00','1') if x=='1/1/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
rep = lambda x: x.replace('1/2/00','2') if x=='1/2/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
rep = lambda x: x.replace('1/3/00','3') if x=='1/3/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
rep = lambda x: x.replace('1/4/00','4') if x=='1/4/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
rep = lambda x: x.replace('1/5/00','5') if x=='1/5/00' else x
ch['number of open complaints'] = ch['number of open complaints'].apply(rep)

# %%
ch
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                 6979.535900              Bachelor      F      0.0
# 2                12887.431700              Bachelor      F  48767.0
# 3                 7645.861800              Bachelor      M      0.0
# 4                 5363.076500  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 8877             23405.987980              Bachelor      M  71941.0
# 8878              3096.511217               College      F  21604.0
# 8879              8163.890428              Bachelor      M      0.0
# 8880              7524.442436               College      M  21941.0
# 8881              2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['number of open complaints'].value_counts()
# Out:
# 0    5421
# 0    1618
# 1     749
# 2     279
# 1     245
# 3     221
# 4     114
# 2      93
# 3      58
# 5      43
# 4      28
# 5      12
# Name: number of open complaints, dtype: int64

# %%
ch['number of open complaints'] = ch['number of open complaints'].fillna(0)
ch
# Out:
#       customer lifetime value             education gender   income  \
# 0                         NaN                Master    NaN      0.0
# 1                 6979.535900              Bachelor      F      0.0
# 2                12887.431700              Bachelor      F  48767.0
# 3                 7645.861800              Bachelor      M      0.0
# 4                 5363.076500  High School or Below      M  36357.0
# ...                       ...                   ...    ...      ...
# 8877             23405.987980              Bachelor      M  71941.0
# 8878              3096.511217               College      F  21604.0
# 8879              8163.890428              Bachelor      M      0.0
# 8880              7524.442436               College      M  21941.0
# 8881              2611.836866               College      M      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['number of open complaints'].value_counts()
# Out:
# 0    5422
# 0    1618
# 1     749
# 2     279
# 1     245
# 3     221
# 4     114
# 2      93
# 3      58
# 5      43
# 4      28
# 5      12
# Name: number of open complaints, dtype: int64

# %% [markdown]
# ## Filtering data and Correcting typos

# %%
ch['gender'].value_counts()
# Out:
# F         4435
# M         4237
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
def clean_gender(x):
    if x in ['M', 'Male',"male"]:
        return 'Male'
    elif x in ['F', 'female',"Femal"]:
        return 'Female'
    elif np.nan:  pass
    else:
        return 'U'

# %%
ch['gender'] = list(map(clean_gender, ch['gender'])) 
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                         NaN                Master    None      0.0
# 1                 6979.535900              Bachelor  Female      0.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male      0.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male      0.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['state'].value_counts()
# Out:
# California    2925
# Oregon        2512
# Arizona       1591
# Nevada         867
# Washington     762
# Cali           120
# AZ              74
# WA              30
# Name: state, dtype: int64

# %%
def clean_state(x):
    if x in ['California', 'Cali']:
        return 'California'
    elif x in ['Arizona', 'AZ']:
        return 'Arizona'
    elif x in ['Washington', 'WA']:
        return 'Washington'
    elif x in ['Nevada']:
        return 'Nevada'
    elif x in ['Oregon']:
        return 'Oregon'
    elif np.nan:  pass
    else:
        return x

# %%
ch['state'] = list(map(clean_state, ch['state'])) 
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                         NaN                Master    None      0.0
# 1                 6979.535900              Bachelor  Female      0.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male      0.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male      0.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['state'].value_counts()
# Out:
# California    3045
# Oregon        2512
# Arizona       1665
# Nevada         867
# Washington     792
# Name: state, dtype: int64

# %%
ch['education'].value_counts()
# Out:
# Bachelor                2655
# College                 2594
# High School or Below    2550
# Master                   727
# Doctor                   331
# Bachelors                 24
# Name: education, dtype: int64

# %%
def clean_education(x):
    if x in ['Bachelor', 'Bachelors']:
        return 'Bachelor'
    else: 
        return x

# %%
ch['education'] = list(map(clean_education, ch['education'])) 
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                         NaN                Master    None      0.0
# 1                 6979.535900              Bachelor  Female      0.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male      0.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male      0.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %% [markdown]
# Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values)
# Hint: numpy.nan is considered of float64 data type.

# %%
mean_customer_lifetime_value = int(np.mean(ch['customer lifetime value']))
mean_customer_lifetime_value
# Out:
# 7983

# %%
ch['customer lifetime value'] = ch['customer lifetime value'].fillna(mean_customer_lifetime_value)
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None      0.0
# 1                 6979.535900              Bachelor  Female      0.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male      0.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male      0.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male      0.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['income'] = ch['income'].replace(0,np.NaN)
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None      NaN
# 1                 6979.535900              Bachelor  Female      NaN
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male      NaN
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male      NaN
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
mean_income = int(np.mean(ch['income']))
mean_income
# Out:
# 50707

# %%
ch['income'] = ch['income'].fillna(mean_income)
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male  50707.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#            state  total claim amount  vehicle class
# 0     Washington            2.704934  Four-Door Car
# 1        Arizona         1131.464935  Four-Door Car
# 2         Nevada          566.472247   Two-Door Car
# 3     California          529.881344            SUV
# 4     Washington           17.269323  Four-Door Car
# ...          ...                 ...            ...
# 8877  California          198.234764  Four-Door Car
# 8878  California          379.200000  Four-Door Car
# 8879  California          790.784983  Four-Door Car
# 8880  California          691.200000  Four-Door Car
# 8881  California          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8882 entries, 0 to 8881
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer lifetime value    8882 non-null   float64
#  1   education                  8881 non-null   object
#  2   gender                     8759 non-null   object
#  3   income                     8882 non-null   float64
#  4   monthly premium auto       8881 non-null   float64
#  5   number of open complaints  8882 non-null   object
#  6   policy type                8881 non-null   object
#  7   state                      8881 non-null   object
#  8   total claim amount         8881 non-null   float64
#  9   vehicle class              8881 non-null   object
# dtypes: float64(4), object(6)
# memory usage: 694.0+ KB

# %% [markdown]
# - Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central

# %%
def clean_st(x):
    if x in ['California']:
        return 'West Region'
    elif x in ['Arizona', 'Nevada']:
        return 'Central'
    elif x in ['Washington']:
        return 'East'
    elif x in ['Oregon']:
        return 'Noth West'
    elif np.nan:  pass
    else:
        return x

# %%
ch['state'] = list(map(clean_st, ch['state'])) 
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male  50707.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8877  West Region          198.234764  Four-Door Car
# 8878  West Region          379.200000  Four-Door Car
# 8879  West Region          790.784983  Four-Door Car
# 8880  West Region          691.200000  Four-Door Car
# 8881  West Region          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['state'].value_counts()
# Out:
# West Region    3045
# Central        2532
# Noth West      2512
# East            792
# Name: state, dtype: int64

# %% [markdown]
# (Optional) In the column `Vehicle Class`, nerge the two categories `Luxury SUV` and `Luxury Car` into one category named `Luxury Vehicle`

# %%
def clean_vehicle_class(x):
    if x in ['Luxury SUV','Luxury Car']:
        return 'Luxury Vehicle'
    else:
        return x

# %%
ch['vehicle class'] = list(map(clean_vehicle_class, ch['vehicle class'])) 
ch
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8877             23405.987980              Bachelor    Male  71941.0
# 8878              3096.511217               College  Female  21604.0
# 8879              8163.890428              Bachelor    Male  50707.0
# 8880              7524.442436               College    Male  21941.0
# 8881              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8877                  73.0                         0   Personal Auto
# 8878                  79.0                         0  Corporate Auto
# 8879                  85.0                         3  Corporate Auto
# 8880                  96.0                         0   Personal Auto
# 8881                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8877  West Region          198.234764  Four-Door Car
# 8878  West Region          379.200000  Four-Door Car
# 8879  West Region          790.784983  Four-Door Car
# 8880  West Region          691.200000  Four-Door Car
# 8881  West Region          369.600000   Two-Door Car
#
# [8882 rows x 10 columns]

# %%
ch['vehicle class'].value_counts()
# Out:
# Four-Door Car     4527
# Two-Door Car      1834
# SUV               1717
# Sports Car         463
# Luxury Vehicle     340
# Name: vehicle class, dtype: int64

# %% [markdown]
#  ### (Optional) Removing outliers using 1.5*IQR technique for all numerical columns.

# %%
arr=ch['customer lifetime value']

# %%
def outlier_treatment(customer_lifetime):
    arr.sort_values
    Q1 = np.percentile(arr, [25])
    Q3 = np.percentile(arr, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lowerbound,upperbound = outlier_treatment(arr)

# %%
lowerbound
# Out:
# array([-3440.40164913])

# %%
upperbound
# Out:
# array([16347.05502988])

# %%
ch.drop(ch[ (arr > upperbound[0]) | (arr < lowerbound[0]) ].index , inplace=True)

# %%
f=ch.reset_index()
f
# Out:
#       index  customer lifetime value             education  gender   income  \
# 0         0              7983.000000                Master    None  50707.0
# 1         1              6979.535900              Bachelor  Female  50707.0
# 2         2             12887.431700              Bachelor  Female  48767.0
# 3         3              7645.861800              Bachelor    Male  50707.0
# 4         4              5363.076500  High School or Below    Male  36357.0
# ...     ...                      ...                   ...     ...      ...
# 8080   8876              4100.398533               College  Female  47761.0
# 8081   8878              3096.511217               College  Female  21604.0
# 8082   8879              8163.890428              Bachelor    Male  50707.0
# 8083   8880              7524.442436               College    Male  21941.0
# 8084   8881              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8080                 104.0                         0   Personal Auto
# 8081                  79.0                         0  Corporate Auto
# 8082                  85.0                         3  Corporate Auto
# 8083                  96.0                         0   Personal Auto
# 8084                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8080  West Region          541.282007  Four-Door Car
# 8081  West Region          379.200000  Four-Door Car
# 8082  West Region          790.784983  Four-Door Car
# 8083  West Region          691.200000  Four-Door Car
# 8084  West Region          369.600000   Two-Door Car
#
# [8085 rows x 11 columns]

# %%
def drop_columns(f) :
    f.drop(columns=["index"], inplace=True)
    return f

# %%
drop_columns(f)
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8080              4100.398533               College  Female  47761.0
# 8081              3096.511217               College  Female  21604.0
# 8082              8163.890428              Bachelor    Male  50707.0
# 8083              7524.442436               College    Male  21941.0
# 8084              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8080                 104.0                         0   Personal Auto
# 8081                  79.0                         0  Corporate Auto
# 8082                  85.0                         3  Corporate Auto
# 8083                  96.0                         0   Personal Auto
# 8084                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8080  West Region          541.282007  Four-Door Car
# 8081  West Region          379.200000  Four-Door Car
# 8082  West Region          790.784983  Four-Door Car
# 8083  West Region          691.200000  Four-Door Car
# 8084  West Region          369.600000   Two-Door Car
#
# [8085 rows x 10 columns]

# %%
inc=f['income']
inc
# Out:
# 0       50707.0
# 1       50707.0
# 2       48767.0
# 3       50707.0
# 4       36357.0
#          ...
# 8080    47761.0
# 8081    21604.0
# 8082    50707.0
# 8083    21941.0
# 8084    50707.0
# Name: income, Length: 8085, dtype: float64

# %%
def outlier_income(income):
    inc.sort_values
    Q1 = np.percentile(inc, [25])
    Q3 = np.percentile(inc, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lower,upper = outlier_income(inc)

# %%
lower
# Out:
# array([-6961.5])

# %%
upper
# Out:
# array([104010.5])

# %%
f.drop(f[ (inc > upper[0]) | (inc < lower[0]) ].index , inplace=True)

# %%
f
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8080              4100.398533               College  Female  47761.0
# 8081              3096.511217               College  Female  21604.0
# 8082              8163.890428              Bachelor    Male  50707.0
# 8083              7524.442436               College    Male  21941.0
# 8084              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8080                 104.0                         0   Personal Auto
# 8081                  79.0                         0  Corporate Auto
# 8082                  85.0                         3  Corporate Auto
# 8083                  96.0                         0   Personal Auto
# 8084                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8080  West Region          541.282007  Four-Door Car
# 8081  West Region          379.200000  Four-Door Car
# 8082  West Region          790.784983  Four-Door Car
# 8083  West Region          691.200000  Four-Door Car
# 8084  West Region          369.600000   Two-Door Car
#
# [8085 rows x 10 columns]

# %%
#No outliers in income

# %%
auto=f['monthly premium auto']
auto
# Out:
# 0       1000.0
# 1         94.0
# 2        108.0
# 3        106.0
# 4         68.0
#          ...
# 8080     104.0
# 8081      79.0
# 8082      85.0
# 8083      96.0
# 8084      77.0
# Name: monthly premium auto, Length: 8085, dtype: float64

# %%
def outlier_auto(auto):
    auto.sort_values
    Q1 = np.percentile(auto, [25])
    Q3 = np.percentile(auto, [75])
    IQR = Q3-Q1
    lower_range = Q1-(1.5 * IQR)
    upper_range = Q3 + (1.5 * IQR)
    return lower_range,upper_range

# %%
lower,upper = outlier_income(auto)

# %%
f.drop(f[ (auto > upper[0]) | (auto < lower[0]) ].index , inplace=True)

# %%
f
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8080              4100.398533               College  Female  47761.0
# 8081              3096.511217               College  Female  21604.0
# 8082              8163.890428              Bachelor    Male  50707.0
# 8083              7524.442436               College    Male  21941.0
# 8084              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8080                 104.0                         0   Personal Auto
# 8081                  79.0                         0  Corporate Auto
# 8082                  85.0                         3  Corporate Auto
# 8083                  96.0                         0   Personal Auto
# 8084                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8080  West Region          541.282007  Four-Door Car
# 8081  West Region          379.200000  Four-Door Car
# 8082  West Region          790.784983  Four-Door Car
# 8083  West Region          691.200000  Four-Door Car
# 8084  West Region          369.600000   Two-Door Car
#
# [8085 rows x 10 columns]

# %%
tot_claims=f['total claim amount']

# %%
lower,upper = outlier_income(tot_claims)

# %%
f.drop(f[ ( tot_claims> upper[0]) | (tot_claims < lower[0]) ].index , inplace=True)

# %%
f
# Out:
#       customer lifetime value             education  gender   income  \
# 0                 7983.000000                Master    None  50707.0
# 1                 6979.535900              Bachelor  Female  50707.0
# 2                12887.431700              Bachelor  Female  48767.0
# 3                 7645.861800              Bachelor    Male  50707.0
# 4                 5363.076500  High School or Below    Male  36357.0
# ...                       ...                   ...     ...      ...
# 8080              4100.398533               College  Female  47761.0
# 8081              3096.511217               College  Female  21604.0
# 8082              8163.890428              Bachelor    Male  50707.0
# 8083              7524.442436               College    Male  21941.0
# 8084              2611.836866               College    Male  50707.0
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                         0   Personal Auto
# 1                     94.0                         0   Personal Auto
# 2                    108.0                         0   Personal Auto
# 3                    106.0                         0  Corporate Auto
# 4                     68.0                         0   Personal Auto
# ...                    ...                       ...             ...
# 8080                 104.0                         0   Personal Auto
# 8081                  79.0                         0  Corporate Auto
# 8082                  85.0                         3  Corporate Auto
# 8083                  96.0                         0   Personal Auto
# 8084                  77.0                         0  Corporate Auto
#
#             state  total claim amount  vehicle class
# 0            East            2.704934  Four-Door Car
# 1         Central         1131.464935  Four-Door Car
# 2         Central          566.472247   Two-Door Car
# 3     West Region          529.881344            SUV
# 4            East           17.269323  Four-Door Car
# ...           ...                 ...            ...
# 8080  West Region          541.282007  Four-Door Car
# 8081  West Region          379.200000  Four-Door Car
# 8082  West Region          790.784983  Four-Door Car
# 8083  West Region          691.200000  Four-Door Car
# 8084  West Region          369.600000   Two-Door Car
#
# [8085 rows x 10 columns]
