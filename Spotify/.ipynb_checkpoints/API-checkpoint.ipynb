# %%
from  config import *

# %%
import spotipy
import json
import pandas as pd
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

from spotipy import *

# %%
#Initialize SpotiPy with user credentias
sp = Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %%
playlist_1 = sp.user_playlist_tracks("spotify", "5oZjXwvrbAJ29Beza3h1bn",market="GB")

# %%
playlist_2 = sp.user_playlist_tracks("spotify", "5Q7JPVmkNBFbPF5QVJFLds",market="GB")

# %%
playlist_3 = sp.user_playlist_tracks("spotify", "72LA3OR3WCoXu6ZC7opyz9",market="GB")

# %%
playlist_4 = sp.user_playlist_tracks("spotify", "1YAavrvwmv0fANXM9JxuHk",market="GB")

# %%
playlist_5 = sp.user_playlist_tracks("spotify", "5iqZs4HHMnJuVOaT6uYGrW",market="GB")

# %%
playlist_6 = sp.user_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs",market="GB")

# %%
playlist_7 = sp.user_playlist_tracks("spotify", "3O9P4HKyiYJ2npdqdJEsrd",market="GB")

# %%
playlist_8 = sp.user_playlist_tracks("spotify", "3sJmyHc2fYGgwSHhrVNi9c",market="GB")

# %%
playlist_9 = sp.user_playlist_tracks("spotify", "5ZeXDT6QlIU0Vihekgw1JI",market="GB")

# %%
playlist_10 = sp.user_playlist_tracks("spotify", "2PjVPkj4a9kBvQIXaZ6UUt",market="GB")

# %%
playlist_1["items"][0]["track"]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LArUyIoMiHmDvvOAsE2cd'},
#     'href': 'https://api.spotify.com/v1/artists/6LArUyIoMiHmDvvOAsE2cd',
#     'id': '6LArUyIoMiHmDvvOAsE2cd',
#     'name': 'Dream',
#     'type': 'artist',
#     'uri': 'spotify:artist:6LArUyIoMiHmDvvOAsE2cd'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jeXY6LJU0ZiKhXoXa9rRw'},
#     'href': 'https://api.spotify.com/v1/artists/3jeXY6LJU0ZiKhXoXa9rRw',
#     'id': '3jeXY6LJU0ZiKhXoXa9rRw',
#     'name': 'PmBata',
#     'type': 'artist',
#     'uri': 'spotify:artist:3jeXY6LJU0ZiKhXoXa9rRw'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4nndDRqggBACyN5dw13kDI'},
#   'href': 'https://api.spotify.com/v1/albums/4nndDRqggBACyN5dw13kDI',
#   'id': '4nndDRqggBACyN5dw13kDI',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273803534b1316c44da0111c635',
#     'width': 640},
# ...

# %%
#items = []
#for i in range(1,11):
    #items.extend(locals()['playlist_'+str(i)]["items"])

# %% [markdown]
# genre = []
# for track in items:
#     #Main Artist
#     artist_uri = track["track"]["artists"][0]["uri"]
#     artist_info = sp.artist(artist_uri)
#
#     #Name, popularity, genre
#     artist_name =track["track"]["artists"][0]["name"]
#     artist_pop = artist_info["popularity"]
#     artist_genres = artist_info["genres"]
#     genre.append(artist_genres)
#
# genre_clean = []
# for x in genre:
#     if x == []:
#         genre_clean.append('NA')
#     else:
#         genre_clean.append(x[0])

# %%
playlist_1.update(playlist_2)
playlist_1.update(playlist_3)
playlist_1.update(playlist_4)
playlist_1.update(playlist_5)
playlist_1.update(playlist_6)
playlist_1.update(playlist_7)
playlist_1.update(playlist_8)
playlist_1.update(playlist_9)
playlist_1.update(playlist_10)

# %%
playlist_1
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2PjVPkj4a9kBvQIXaZ6UUt/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-06-24T15:30:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/dgdeccaclassics'},
#     'href': 'https://api.spotify.com/v1/users/dgdeccaclassics',
#     'id': 'dgdeccaclassics',
#     'type': 'user',
#     'uri': 'spotify:user:dgdeccaclassics'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OzxPXyowUEQ532c9AmHUR'},
#        'href': 'https://api.spotify.com/v1/artists/0OzxPXyowUEQ532c9AmHUR',
#        'id': '0OzxPXyowUEQ532c9AmHUR',
#        'name': 'Giacomo Puccini',
#        'type': 'artist',
#        'uri': 'spotify:artist:0OzxPXyowUEQ532c9AmHUR'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4leT3QmSGt6qmfuwvrIB2o'},
# ...

# %%
#genre_clean

# %%
print(list(playlist_1.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist_1["total"]) #  Let's check items:
len(playlist_1["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  10000
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks
# Out:
# [{'added_at': '2021-11-21T01:07:04Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/2n186b3dvgyqlvre2bvmw2dji'},
#    'href': 'https://api.spotify.com/v1/users/2n186b3dvgyqlvre2bvmw2dji',
#    'id': '2n186b3dvgyqlvre2bvmw2dji',
#    'type': 'user',
#    'uri': 'spotify:user:2n186b3dvgyqlvre2bvmw2dji'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6LArUyIoMiHmDvvOAsE2cd'},
#       'href': 'https://api.spotify.com/v1/artists/6LArUyIoMiHmDvvOAsE2cd',
#       'id': '6LArUyIoMiHmDvvOAsE2cd',
#       'name': 'Dream',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LArUyIoMiHmDvvOAsE2cd'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3jeXY6LJU0ZiKhXoXa9rRw'},
#       'href': 'https://api.spotify.com/v1/artists/3jeXY6LJU0ZiKhXoXa9rRw',
#       'id': '3jeXY6LJU0ZiKhXoXa9rRw',
# ...

# %%
tracks=get_playlist_tracks("spotify", "5oZjXwvrbAJ29Beza3h1bn")

# %%
tracks_2=get_playlist_tracks("spotify", "5Q7JPVmkNBFbPF5QVJFLds")

# %%
tracks.extend(tracks_2)

# %%
tracks_3=get_playlist_tracks("spotify", "72LA3OR3WCoXu6ZC7opyz9")

# %%
tracks.extend(tracks_3)

# %%
tracks_4=get_playlist_tracks("spotify", "1YAavrvwmv0fANXM9JxuHk")

# %%
tracks.extend(tracks_4)

# %%
tracks_5=get_playlist_tracks("spotify", "5iqZs4HHMnJuVOaT6uYGrW")

# %%
tracks.extend(tracks_5)

# %%
tracks_6=get_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs")

# %%
tracks.extend(tracks_6)

# %%
tracks_7=get_playlist_tracks("spotify", "3O9P4HKyiYJ2npdqdJEsrd")

# %%
tracks.extend(tracks_7)

# %%
tracks_8=get_playlist_tracks("spotify", "3sJmyHc2fYGgwSHhrVNi9c")

# %%
tracks.extend(tracks_8)

# %%
tracks_9=get_playlist_tracks("spotify", "5ZeXDT6QlIU0Vihekgw1JI")

# %%
tracks.extend(tracks_9)

# %%
tracks_10=get_playlist_tracks("spotify", "2PjVPkj4a9kBvQIXaZ6UUt")

# %%
tracks.extend(tracks_10)

# %%
len(tracks)
# Out:
# 41267

# %%
for track in playlist["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]

# %%
import csv
with open('list_of_audio_features1.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerow(list_of_audio_features1)

# %%
def Extract_features_from_playlist(playlist, range1, range2):
    list_of_audio_features=[]
    for item in range(range1,range2):
        if item%200 == 0:
            print(item)
        #print (tracks[item]["track"]["id"])
        list_of_audio_features.append(sp.audio_features(playlist[item]["track"]["id"])[0])
    df = pd.DataFrame(list_of_audio_features)
    df.to_csv(f'df_{range1}.csv', index=False)
    return df

# %%
df1 = Extract_features_from_playlist(tracks, 0, 1000)
#list_of_audio_features3 = Extract_features_from_playlist(tracks, 2001, 3000)
df1
# Out:
# 0
# 200
# 400
# 600
# 800
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.459   0.581   10    -6.575     1       0.0713       0.31600
# 1           0.636   0.749    1    -4.197     1       0.0631       0.19500
# 2           0.597   0.595    9    -7.328     1       0.2260       0.56300
# 3           0.729   0.662    1    -4.851     1       0.0718       0.12600
# 4           0.482   0.826    7    -9.312     1       0.1040       0.01640
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.391   0.769   11    -6.356     1       0.0450       0.00346
# 996         0.362   0.421   10   -11.699     1       0.0372       0.28100
# 997         0.603   0.886    5    -3.777     0       0.0837       0.00045
# 998         0.454   0.700    7    -6.222     1       0.0264       0.06490
# 999         0.494   0.720    7    -5.093     1       0.0568       0.39800
#
# ...

# %%
df2 = Extract_features_from_playlist(tracks, 1000, 2000)
df2
# Out:
# 1000
# 1200
# 1400
# 1600
# 1800
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.558   0.408    2    -8.235     1       0.0253       0.05000
# 1           0.572   0.712    2    -6.085     1       0.0336       0.15400
# 2           0.545   0.472   11    -7.552     1       0.0279       0.43400
# 3           0.511   0.640    5    -7.161     1       0.0276       0.09170
# 4           0.331   0.427    3    -7.431     1       0.0302       0.49800
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.595   0.839    2    -4.670     1       0.0317       0.05980
# 996         0.479   0.545    7    -7.346     1       0.0688       0.36500
# 997         0.557   0.442    5    -7.224     1       0.0243       0.73100
# 998         0.566   0.815    9    -4.481     0       0.1400       0.07370
# 999         0.517   0.906    1    -3.677     1       0.0735       0.00272
#
# ...

# %%
df3 = Extract_features_from_playlist(tracks, 2500, 3000)
df3
# Out:
# 2600
# 2800
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.714   0.686   11    -6.333     1       0.0445      0.203000
# 1           0.295   0.312    1    -5.895     1       0.0323      0.910000
# 2           0.548   0.420    0    -7.842     1       0.0277      0.198000
# 3           0.301   0.901    6    -4.806     1       0.1030      0.000077
# 4           0.395   0.438    1    -7.958     1       0.0333      0.488000
# ..            ...     ...  ...       ...   ...          ...           ...
# 495         0.739   0.646    8    -7.556     1       0.3570      0.124000
# 496         0.710   0.570    1    -6.499     1       0.4780      0.167000
# 497         0.720   0.737    5    -4.119     1       0.1200      0.352000
# 498         0.867   0.774   11    -5.791     0       0.3150      0.110000
# 499         0.848   0.649    2    -6.083     1       0.3150      0.232000
#
# ...

# %%
df14 = Extract_features_from_playlist(tracks, 40000, 41267)
df14
# Out:
# 40000
# 40200
# 40400
# 40600
# 40800
# 41000
# 41200
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.554  0.7520    6    -4.286     1       0.0249        0.1600
# 1            0.635  0.7720    7    -4.825     1       0.0279        0.2160
# 2            0.590  0.8550    6    -4.562     1       0.0358        0.0651
# 3            0.630  0.8360    7    -4.591     1       0.0438        0.5410
# 4            0.600  0.9420    2    -4.441     1       0.0402        0.1690
# ...            ...     ...  ...       ...   ...          ...           ...
# 1262         0.197  0.1210   11   -20.192     1       0.0583        0.9760
# 1263         0.140  0.0179    6   -28.038     0       0.0550        0.9620
# 1264         0.235  0.0886    9   -20.041     0       0.0546        0.9650
# 1265         0.235  0.0594    4   -21.228     1       0.0481        0.9890
# 1266         0.322  0.1060    2   -18.952     1       0.0562        0.9710
#
# ...

# %%
dfs = ['df_0.csv', 'df_1000.csv', 'df_1500.csv', 'df_2000.csv', 'df_2500.csv', 'df_4000.csv','df_6000.csv','df_7000.csv','df_9000.csv','df_13000.csv','df_13500.csv','df_14000.csv','df_15000.csv','df_16000.csv','df_18000.csv','df_19000.csv','df_40000.csv']

for i, el in enumerate(dfs):
    if i ==0:
        list_of_audio = pd.DataFrame(pd.read_csv(el))
    else:
        list_of_audio = pd.concat([list_of_audio, pd.read_csv(el)], ignore_index=True)

# %%
list_of_audio
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.459  0.5810   10    -6.575     1       0.0713        0.3160
# 1             0.636  0.7490    1    -4.197     1       0.0631        0.1950
# 2             0.597  0.5950    9    -7.328     1       0.2260        0.5630
# 3             0.729  0.6620    1    -4.851     1       0.0718        0.1260
# 4             0.482  0.8260    7    -9.312     1       0.1040        0.0164
# ...             ...     ...  ...       ...   ...          ...           ...
# 13867         0.197  0.1210   11   -20.192     1       0.0583        0.9760
# 13868         0.140  0.0179    6   -28.038     0       0.0550        0.9620
# 13869         0.235  0.0886    9   -20.041     0       0.0546        0.9650
# 13870         0.235  0.0594    4   -21.228     1       0.0481        0.9890
# 13871         0.322  0.1060    2   -18.952     1       0.0562        0.9710
#
# ...

# %%
#list_of_audio=pd.concat([df1, df2, df3,df4], ignore_index=True)
#list_of_audio

# %%
import numpy as np
df=pd.DataFrame(list_of_audio)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0             0.459  0.5810    -6.575       0.0713        0.3160
# 1             0.636  0.7490    -4.197       0.0631        0.1950
# 2             0.597  0.5950    -7.328       0.2260        0.5630
# 3             0.729  0.6620    -4.851       0.0718        0.1260
# 4             0.482  0.8260    -9.312       0.1040        0.0164
# ...             ...     ...       ...          ...           ...
# 13867         0.197  0.1210   -20.192       0.0583        0.9760
# 13868         0.140  0.0179   -28.038       0.0550        0.9620
# 13869         0.235  0.0886   -20.041       0.0546        0.9650
# 13870         0.235  0.0594   -21.228       0.0481        0.9890
# 13871         0.322  0.1060   -18.952       0.0562        0.9710
#
#        instrumentalness  liveness  valence    tempo                      id  \
# 0              0.000000     0.124   0.4900  176.195  4Agtk2MrapdZAVN7v6PuFO
# ...

# %%
df_numerical = df[['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
df_numerical
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0             0.459  0.5810    -6.575       0.0713        0.3160
# 1             0.636  0.7490    -4.197       0.0631        0.1950
# 2             0.597  0.5950    -7.328       0.2260        0.5630
# 3             0.729  0.6620    -4.851       0.0718        0.1260
# 4             0.482  0.8260    -9.312       0.1040        0.0164
# ...             ...     ...       ...          ...           ...
# 13867         0.197  0.1210   -20.192       0.0583        0.9760
# 13868         0.140  0.0179   -28.038       0.0550        0.9620
# 13869         0.235  0.0886   -20.041       0.0546        0.9650
# 13870         0.235  0.0594   -21.228       0.0481        0.9890
# 13871         0.322  0.1060   -18.952       0.0562        0.9710
#
#        instrumentalness  liveness  valence    tempo
# 0              0.000000     0.124   0.4900  176.195
# 1              0.000000     0.107   0.6530  117.904
# ...

# %%
X=df_numerical 
X
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0             0.459  0.5810    -6.575       0.0713        0.3160
# 1             0.636  0.7490    -4.197       0.0631        0.1950
# 2             0.597  0.5950    -7.328       0.2260        0.5630
# 3             0.729  0.6620    -4.851       0.0718        0.1260
# 4             0.482  0.8260    -9.312       0.1040        0.0164
# ...             ...     ...       ...          ...           ...
# 13867         0.197  0.1210   -20.192       0.0583        0.9760
# 13868         0.140  0.0179   -28.038       0.0550        0.9620
# 13869         0.235  0.0886   -20.041       0.0546        0.9650
# 13870         0.235  0.0594   -21.228       0.0481        0.9890
# 13871         0.322  0.1060   -18.952       0.0562        0.9710
#
#        instrumentalness  liveness  valence    tempo
# 0              0.000000     0.124   0.4900  176.195
# 1              0.000000     0.107   0.6530  117.904
# ...

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %%
X.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  13872.000000  13872.000000  13872.000000  13872.000000  13872.000000
# mean       0.538243      0.692328     -7.359230      0.079883      0.213325
# std        0.173546      0.226523      3.698765      0.082070      0.278304
# min        0.000000      0.002090    -38.575000      0.000000      0.000000
# 25%        0.416000      0.539000     -9.042000      0.034900      0.004155
# 50%        0.539000      0.734000     -6.557000      0.048100      0.069700
# 75%        0.668000      0.883000     -4.802750      0.086000      0.344000
# max        0.982000      1.000000      1.646000      0.950000      0.996000
#
#        instrumentalness      liveness       valence         tempo
# count      13872.000000  13872.000000  13872.000000  13872.000000
# mean           0.090772      0.205313      0.472774    124.512989
# std            0.227927      0.176164      0.244258     29.759428
# ...

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns = X.columns)
display(X.head())
print()
display(X_scaled_df.head())
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.459   0.581    -6.575       0.0713        0.3160
# 1         0.636   0.749    -4.197       0.0631        0.1950
# 2         0.597   0.595    -7.328       0.2260        0.5630
# 3         0.729   0.662    -4.851       0.0718        0.1260
# 4         0.482   0.826    -9.312       0.1040        0.0164
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000000     0.124    0.490  176.195
# 1          0.000000     0.107    0.653  117.904
# 2          0.000002     0.291    0.592  169.810
# 3          0.000000     0.324    0.875  153.015
# 4          0.000027     0.218    0.884  187.025
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.456629 -0.491483  0.212032    -0.104589      0.368945
# 1      0.563309  0.250190  0.854973    -0.204507     -0.065848
# 2      0.338577 -0.429677  0.008444     1.780449      1.256496
# ...

# %%
with open("Model/scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  1.387200e+04  1.387200e+04  1.387200e+04  1.387200e+04  1.387200e+04
# mean   8.667135e-16  1.338798e-16  1.936488e-16  2.356703e-16 -1.106061e-16
# std    1.000036e+00  1.000036e+00  1.000036e+00  1.000036e+00  1.000036e+00
# min   -3.101556e+00 -3.047207e+00 -8.439816e+00 -9.733874e-01 -7.665463e-01
# 25%   -7.044112e-01 -6.769008e-01 -4.549711e-01 -5.481268e-01 -7.516160e-01
# 50%    4.359908e-03  1.839693e-01  2.168990e-01 -3.872833e-01 -5.160915e-01
# 75%    7.477052e-01  8.417623e-01  6.911961e-01  7.453255e-02  4.695576e-01
# max    2.557088e+00  1.358284e+00  2.434746e+00  1.060247e+01  2.812406e+00
#
#        instrumentalness      liveness       valence         tempo
# count      1.387200e+04  1.387200e+04  1.387200e+04  1.387200e+04
# mean      -2.067814e-15  3.053353e-16  7.548748e-17  4.562703e-16
# std        1.000036e+00  1.000036e+00  1.000036e+00  1.000036e+00
# ...

# %%
kmeans = KMeans(n_clusters=30, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=30, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([ 1,  0, 23, ...,  6,  6,  6])

# %%
# assign a cluster to each example
labels = kmeans.predict(X_scaled_df)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(X.to_numpy()[row_ix, 1], X.to_numpy()[row_ix, 3])
    # show the plot
pyplot.show()

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     752
# 1     583
# 2     613
# 3     108
# 4     428
# 5     537
# 6     303
# 7     324
# 8     149
# 9     245
# 10    957
# 11    907
# 12    176
# 13    654
# 14    647
# 15    424
# 16    555
# 17    490
# 18    673
# 19    204
# 20    201
# 21    686
# 22     95
# 23    366
# 24    589
# 25    303
# 26    660
# 27    469
# 28    472
# 29    302
# dtype: int64

# %%
#X_df = pd.DataFrame(X)
X["cluster"] = clusters
X
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_43168\3390344749.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["cluster"] = clusters
#        danceability  energy  loudness  speechiness  acousticness  \
# 0             0.459  0.5810    -6.575       0.0713        0.3160
# 1             0.636  0.7490    -4.197       0.0631        0.1950
# 2             0.597  0.5950    -7.328       0.2260        0.5630
# 3             0.729  0.6620    -4.851       0.0718        0.1260
# 4             0.482  0.8260    -9.312       0.1040        0.0164
# ...             ...     ...       ...          ...           ...
# 13867         0.197  0.1210   -20.192       0.0583        0.9760
# 13868         0.140  0.0179   -28.038       0.0550        0.9620
# ...

# %%
df["cluster"] = clusters
df
# Out:
#        danceability  energy  loudness  speechiness  acousticness  \
# 0             0.459  0.5810    -6.575       0.0713        0.3160
# 1             0.636  0.7490    -4.197       0.0631        0.1950
# 2             0.597  0.5950    -7.328       0.2260        0.5630
# 3             0.729  0.6620    -4.851       0.0718        0.1260
# 4             0.482  0.8260    -9.312       0.1040        0.0164
# ...             ...     ...       ...          ...           ...
# 13867         0.197  0.1210   -20.192       0.0583        0.9760
# 13868         0.140  0.0179   -28.038       0.0550        0.9620
# 13869         0.235  0.0886   -20.041       0.0546        0.9650
# 13870         0.235  0.0594   -21.228       0.0481        0.9890
# 13871         0.322  0.1060   -18.952       0.0562        0.9710
#
#        instrumentalness  liveness  valence    tempo                      id  \
# 0              0.000000     0.124   0.4900  176.195  4Agtk2MrapdZAVN7v6PuFO
# ...

# %%
X[X['cluster'] == 7].sample()
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 8905         0.344   0.994    -2.576       0.0993         0.114
#
#       instrumentalness  liveness  valence    tempo  cluster
# 8905            0.0338     0.753   0.0571  128.038        7

# %%
kmeans.inertia_
# Out:
# 37306.716227145065

# %%
kmeans2 = KMeans(n_clusters=30,
                init="k-means++",
                n_init=100,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=1,
                tol=0,
                algorithm="full",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 39721.57618113252

# %%
K = range(2, 31)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)


import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
#
# Training a K-Means model with 21 clusters!
#
# Training a K-Means model with 22 clusters!
#
# ...

# %%
K = range(2, 35)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    
    filename = "Model/kmeans_" + str(k) + ".pickle"
    with open(filename, "wb") as f:
        pickle.dump(kmeans,f)
    
    silhouette.append(silhouette_score(X_scaled_df, kmeans.predict(X_scaled_df)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Silhouette Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Silhouette Method showing the optimal k')

# %%
 user_song=input() # input a song you like
# Out:
# the ha ha wall the libertines

# %%
results=sp.search(user_song, limit=1)

# %%
track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '0r8wlONS3UlP54390AAgqv'

# %%
for song in range(1):
    print(sp.search(user_song, limit=7)["tracks"]["items"][song]["name"])
# Out:
# The Ha Ha Wall

# %%
for i in range(1):
    artist = results["tracks"]["items"][i]["artists"][0]["name"]
    album = results["tracks"]["items"][i]["album"]["name"]
    print(i ,"Artist:",artist, "\n Album:",album)
# Out:
# 0 Artist: The Libertines
#  Album: The Libertines

# %%
from IPython.display import IFrame

#track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0r8wlONS3UlP54390AAgqv?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
user_song_df=pd.DataFrame(sp.audio_features(track_id))
U=user_song_df.drop(["id","uri","type","track_href","analysis_url","key","mode","time_signature","duration_ms"], axis=1)
U
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.327   0.939     -3.88       0.0432        0.0105
#
#    instrumentalness  liveness  valence    tempo
# 0          0.000134     0.321    0.459  168.088

# %%
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!") 

scaler = load("Model/scaler.pickle")

# %%
new_song = scaler.transform(U)
new_song
# Out:
# array([[-1.21726177,  1.08898647,  0.94068026, -0.44699039, -0.72881634,
#         -0.39767551,  0.65671996, -0.05639277,  1.464295  ]])

# %%
#scaler = StandardScaler()
#scaler.fit(U)
new_song = scaler.transform(U)
new_song_scaled = pd.DataFrame(new_song, columns = U.columns)

new_song_scaled
# Out:
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -1.217262  1.088986   0.94068     -0.44699     -0.728816
#
#    instrumentalness  liveness   valence     tempo
# 0         -0.397676   0.65672 -0.056393  1.464295

# %%
kmeans_30 = load("Model/kmeans_30.pickle")
kmeans_30
# Out:
# KMeans(n_clusters=30, random_state=1234)

# %%
cluster=kmeans_30.predict(new_song_scaled)
cluster=cluster[0]
cluster
# Out:
# 26

# %%
#df[df['cluster'] == cluster].sample(1)
#df[df["cluster"]==cluster].sample()
recommendation =df[df["cluster"]==cluster].sample()
recommendation_id = recommendation["id"].iloc[0]
#recommendation_id
#display(new_song(id))
#display(new_song(recommendation_id))
IFrame(src="https://open.spotify.com/embed/track/"+recommendation_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1OG0QQa2zZe4QeFwVhCiiA?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
